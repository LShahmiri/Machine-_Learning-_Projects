# %% [markdown]
# <a href="https://colab.research.google.com/github/LShahmiri/Machine-_Learning-_Projects/blob/main/Number_Component_PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib.image import imread
import matplotlib.pyplot as plt

image_raw = imread("/content/drive/MyDrive/mi-excel/before/bib/61.JPG")
print(image_raw.shape)

# Displaying the image
plt.figure(figsize=[15,8])
plt.imshow(image_raw)
# Out:
# (512, 512, 3)

# %%
image_sum = image_raw.sum(axis=2)
print(image_sum.shape)

image_bw = image_sum/image_sum.max()
print(image_bw.max())

plt.figure(figsize=[15,8])
plt.imshow(image_bw, cmap=plt.cm.gray)
# Out:
# (512, 512)
# 1.0

# %%
from sklearn.decomposition import PCA, IncrementalPCA
pca = PCA()
pca.fit(image_bw)

# Getting the cumulative variance

var_cumu = np.cumsum(pca.explained_variance_ratio_)*100

# How many PCs explain 95% of the variance?
k = np.argmax(var_cumu>95)
print("Number of components explaining 95% variance: "+ str(k))
#print("\n")

plt.figure(figsize=[10,5])
plt.title('Cumulative Explained Variance explained by the components')
plt.ylabel('Cumulative Explained variance')
plt.xlabel('Principal components')
plt.axvline(x=k, color="k", linestyle="--")
plt.axhline(y=95, color="r", linestyle="--")
ax = plt.plot(var_cumu)
# Out:
# Number of components explaining 95% variance: 57
